# %% [markdown]
# <a href="https://colab.research.google.com/github/tokyo-source/241b205_Algo_lab/blob/main/lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Searching
# Implement Linear Search. Determine the time required to search for element. Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
#
# - To implement Linear Search, measure its time complexity for searching an element, vary the input size by changing the number of elements in the list, and plot a graph to visualize the relationship between time taken and input size
# - Algorithm:
# 1. Start with the first element of the list.
# 2. Compare the element with the value being searched for.
# 3. If the element matches, return the index.
# 4. If the element does not match, move to the next element and repeat steps 2-3.
# 5. If the end of the list is reached and no match is found, return -1

# %% [markdown]
# - **Created by Dr. Ajay

# %%
# write code for Linear Search and plot a graph to visualize the relationship between time taken and input size
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1

input_sizes = [1000, 2000, 5000, 10000, 20000, 30000, 40000, 50000]
time_taken = []

for n in input_sizes:
    arr = list(range(n))
    key = -1

    start_time = time.time()
    linear_search(arr, key)
    end_time = time.time()

    time_taken.append(end_time - start_time)

plt.figure(figsize=(8, 5))
plt.plot(input_sizes, time_taken, marker='o', color='blue')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Linear Search: Time Complexity Analysis")
plt.grid(True)
plt.show()

# %% [markdown]
# # 2. Searching
# Implement recursive Binary Search. Determine the time required to search an element.Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
# - implement recursive Binary Search, measure its time complexity for searching an element and plot a graph of time taken versus different values of n, the number of elements in the list.
# Algorithm:
# 1. Start with the middle element of the list
# 2. If the middle element matches the element being searched, return the index of the middle element
# 3. If the middle element is greater than the element being searched, recursively call the function on the left half of the list
# 4. If the middle element  is  less than the element  being searched, recursively call the function on the right half of the list
# 5. If the element is not found, return -1

# %%
#Prob_2: write code for recursive Binary Search and plot a graph to visualize the relationship between time taken and input size
import time
import matplotlib.pyplot as plt

def binary_search(arr, low, high, x):
    if high >= low:
        mid = (low + high) // 2

        if arr[mid] == x:
            return mid
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
        else:
            return binary_search(arr, mid + 1, high, x)
    else:
        return -1

def measure_time(n):
    arr = list(range(n))
    x = -1
    start = time.perf_counter()
    binary_search(arr, 0, n - 1, x)
    end = time.perf_counter()
    return end - start

n_values = [100, 500, 1000, 5000, 10000, 20000, 50000]
times = []

for n in n_values:
    times.append(measure_time(n))

plt.plot(n_values, times, marker='o')
plt.xlabel("Number of elements (n)")
plt.ylabel("Time taken (seconds)")
plt.title("Time Complexity of Recursive Binary Search")
plt.grid(True)
plt.show()

# %% [markdown]
# #Prob-3
# Given a text txt [0...n-1] and a pattern pat [0...m-1], write a function search (char pat [ ],char txt [ ]) that prints all occurrences of pat [ ] in txt [ ]. You may assume that n > m.
# - Aim:  To write a function "search" that takes a pattern and a text as input, and outputs all occurrences of the pattern in the text.  Algorithm:
# 1. Initialize an empty list to store the indices where the pattern occurs in the text.
# 2. Loop through each character in the text. For each character, check if the substring starting at that character matches the pattern.
# 3. If there is a match, append the starting index of the substring to the list of occurrences.
# 4. Continue looping through the text until all possible substrings have been checked.
# 5. Return the list of indices where the pattern occurs in the text.

# %%
#write code for Prob-3

def search(pat, txt):
    n = len(txt)
    m = len(pat)
    occurrences = []

    for i in range(n - m + 1):
        j = 0

        while j < m and txt[i + j] == pat[j]:
            j += 1

        if j == m:
            occurrences.append(i)

    return occurrences


text = "ABABDABACDABABCABAB"
pattern = "ABAB"

result = search(pattern, text)

if result:
    print("Pattern found at indices:", result)
else:
    print("Pattern not found")
# Out:
# Pattern found at indices: [0, 10, 15]

# %% [markdown]
# #Prob-4
# Sort a given set of elements using the Insertion sort and determine the time required tosort the elements. Repeat the experiment for different values of n, the number of elements in the list to be sorted and plot a graph of the time taken versus n.
# - Aim :  To Develop a program to implement Insertion sort and determine the time required to sort the elements.
# - Algorithm:
# 1. Iterate over the array from the second element to the end (i = 1 to n-1).
# 2. For each element, compare it to the elements before it (j = i-1 to 0).
# 3. If the current element is smaller, swap it with the element before it.
# 4. Repeat step 3 until the current element is no longer smaller than the previous element.
# 5. Repeat steps 2-4 for all elements in the array.

# %%
#Prob_4: write code for insertion sort and plot a graph to visualize the relationship between time taken and input size
import time
import random
import matplotlib.pyplot as plt

def insertion_sort(arr):
    """
    Sorts a list using the Insertion Sort algorithm
    as described in the problem statement.
    """
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1


        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1


        arr[j + 1] = key

def run_experiment():

    input_sizes = [100, 500, 1000, 1500, 2000, 2500, 3000]
    execution_times = []

    print(f"{'n (Input Size)':<20} | {'Time Taken (seconds)':<20}")
    print("-" * 45)

    for n in input_sizes:

        random_list = [random.randint(0, 10000) for _ in range(n)]


        start_time = time.time()


        insertion_sort(random_list)


        end_time = time.time()


        time_taken = end_time - start_time
        execution_times.append(time_taken)

        print(f"{n:<20} | {time_taken:.6f}")


    plt.figure(figsize=(10, 6))
    plt.plot(input_sizes, execution_times, marker='o', linestyle='-', color='b', label='Insertion Sort')

    plt.title('Time Complexity Analysis: Insertion Sort')
    plt.xlabel('Number of Elements (n)')
    plt.ylabel('Time Taken (seconds)')
    plt.grid(True)
    plt.legend()

    print("\nPlotting graph...")
    plt.show()

if __name__ == "__main__":
    run_experiment()
# Out:
# n (Input Size)       | Time Taken (seconds)
# ---------------------------------------------
# 100                  | 0.000263
# 500                  | 0.005494
# 1000                 | 0.023084
# 1500                 | 0.051293
# 2000                 | 0.097685
# 2500                 | 0.154041
# 3000                 | 0.221842
#
# Plotting graph...

# %% [markdown]
# # Task
# Implement the linear search algorithm, measure its time complexity for various input sizes (n), and plot a graph showing the relationship between input size and time taken, including a summary of the implementation, methodology, and observations from the plot.

# %% [markdown]
# ## Implement Linear Search Function
#
# ### Subtask:
# Complete the `linear_search` function as defined in the provided text cell, ensuring it correctly finds an element and returns its index, or -1 if not found. Also, fix the `n_v` typo.

# %% [markdown]
# **Reasoning**:
# The existing `linear_search` function correctly implements the linear search algorithm; however, there is a typo (`n_v`) that needs to be removed. I will provide the corrected code for the function.

# %%
def linear_search(arr, x):
    for i in range(len(arr)):
       if arr[i] == x:
          return i
    return -1

# %% [markdown]
# ## Prepare Experiment Data
#
# ### Subtask:
# Define a range of input sizes (n values) for which the linear search performance will be measured. For each 'n', create a sorted list of that size to ensure consistent test conditions.

# %% [markdown]
# **Reasoning**:
# The subtask requires importing necessary libraries, defining a range of input sizes, and initializing a list to store execution times. This will be done in a single code block.

# %%
import numpy as np
import time

n_values = [100, 1000, 5000, 10000, 50000, 100000]
times = []

# %% [markdown]
# **Reasoning**:
# The subtask requires generating sorted lists for each defined input size. I will iterate through `n_values` and create a sorted list for each `n`.

# %%
data_lists = []
for n in n_values:
    data_lists.append(np.arange(n)) # Create a sorted list of size n

# %% [markdown]
# **Reasoning**:
# Now that the `data_lists` are prepared, I will iterate through each list, measure the time taken to perform a linear search for an element (specifically, the last element to represent a near worst-case scenario for an element present in the list) using the previously defined `linear_search` function, and store these times in the `times` list.

# %%
for i, n in enumerate(n_values):
    arr = data_lists[i]
    # Search for the last element in the list (or n-1, if the list is 0-indexed)
    # This ensures a consistent search target and often represents a 'worst-case' for finding an element
    element_to_find = n - 1

    start_time = time.time()
    linear_search(arr, element_to_find)
    end_time = time.time()
    times.append(end_time - start_time)

print("Measured times for linear search:", times)
# Out:
# Measured times for linear search: [8.082389831542969e-05, 0.00038433074951171875, 0.0030493736267089844, 0.004379987716674805, 0.03548121452331543, 0.053969621658325195]

# %% [markdown]
# **Reasoning**:
# The next step is to visualize the collected timing data. Plotting the 'times' against 'n_values' will graphically illustrate the relationship between input size and linear search execution time, which is essential for analyzing its time complexity.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(n_values, times, marker='o', linestyle='-')
plt.title('Linear Search Time Complexity')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.xscale('log') # Use a log scale for better visualization if n_values vary widely
plt.yscale('log') # Use a log scale for better visualization if times vary widely
plt.show()

# %% [markdown]
# ## Summary and Analysis
#
# ### Implementation:
# The `linear_search` function was implemented by iterating through the input array `arr` and comparing each element with the target value `x`. If a match is found, the index `i` is returned. If the loop completes without finding the element, -1 is returned.
#
# ### Methodology:
# To determine the time complexity, the experiment involved:
# 1.  Defining a set of varying input sizes (`n_values`: 100, 1000, 5000, 10000, 50000, 100000).
# 2.  For each `n`, a sorted list of that size was generated using `np.arange(n)`.
# 3.  The `linear_search` function was called for each list, searching for the last element (`n-1`), which represents a near worst-case scenario for finding an existing element.
# 4.  The time taken for each search operation was measured using `time.time()` before and after the function call.
# 5.  These measured times were stored in the `times` list.
#
# ### Observations from the Plot:
# The plot titled 'Linear Search Time Complexity' visualizes the relationship between the input size (n) and the time taken (seconds) for the linear search algorithm. Both axes are on a logarithmic scale for better visualization across a wide range of values.
#
# From the plot, it can be observed that as the input size `n` increases, the time taken to perform the linear search also increases. The relationship appears to be approximately linear on a log-log plot, which indicates a polynomial relationship. Specifically, the plot demonstrates that the time taken for linear search scales roughly linearly with the input size `n`. This is consistent with the theoretical time complexity of Linear Search, which is O(n) in the worst and average cases (when the element is found at the end or not found at all), as it may need to scan through all `n` elements.

# %% [markdown]
# ## Summary and Analysis
#
# ### Implementation:
# The `linear_search` function was implemented by iterating through the input array `arr` and comparing each element with the target value `x`. If a match is found, the index `i` is returned. If the loop completes without finding the element, -1 is returned.
#
# ### Methodology:
# To determine the time complexity, the experiment involved:
# 1.  Defining a set of varying input sizes (`n_values`: 100, 1000, 5000, 10000, 50000, 100000).
# 2.  For each `n`, a sorted list of that size was generated using `np.arange(n)`.
# 3.  The `linear_search` function was called for each list, searching for the last element (`n-1`), which represents a near worst-case scenario for finding an existing element.
# 4.  The time taken for each search operation was measured using `time.time()` before and after the function call.
# 5.  These measured times were stored in the `times` list.
#
# ### Observations from the Plot:
# The plot titled 'Linear Search Time Complexity' visualizes the relationship between the input size (n) and the time taken (seconds) for the linear search algorithm. Both axes are on a logarithmic scale for better visualization across a wide range of values.
#
# From the plot, it can be observed that as the input size `n` increases, the time taken to perform the linear search also increases. The relationship appears to be approximately linear on a log-log plot, which indicates a polynomial relationship. Specifically, the plot demonstrates that the time taken for linear search scales roughly linearly with the input size `n`. This is consistent with the theoretical time complexity of Linear Search, which is O(n) in the worst and average cases (when the element is found at the end or not found at all), as it may need to scan through all `n` elements.

# %% [markdown]
# ## Summary and Analysis
#
# ### Implementation:
# The `linear_search` function was implemented by iterating through the input array `arr` and comparing each element with the target value `x`. If a match is found, the index `i` is returned. If the loop completes without finding the element, -1 is returned.
#
# ### Methodology:
# To determine the time complexity, the experiment involved:
# 1.  Defining a set of varying input sizes (`n_values`: 100, 1000, 5000, 10000, 50000, 100000).
# 2.  For each `n`, a sorted list of that size was generated using `np.arange(n)`.
# 3.  The `linear_search` function was called for each list, searching for the last element (`n-1`), which represents a near worst-case scenario for finding an existing element.
# 4.  The time taken for each search operation was measured using `time.time()` before and after the function call.
# 5.  These measured times were stored in the `times` list.
#
# ### Observations from the Plot:
# The plot titled 'Linear Search Time Complexity' visualizes the relationship between the input size (n) and the time taken (seconds) for the linear search algorithm. Both axes are on a logarithmic scale for better visualization across a wide range of values.
#
# From the plot, it can be observed that as the input size `n` increases, the time taken to perform the linear search also increases. The relationship appears to be approximately linear on a log-log plot, which indicates a polynomial relationship. Specifically, the plot demonstrates that the time taken for linear search scales roughly linearly with the input size `n`. This is consistent with the theoretical time complexity of Linear Search, which is O(n) in the worst and average cases (when the element is found at the end or not found at all), as it may need to scan through all `n` elements.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `linear_search` function was correctly implemented to iterate through an array and return the index of a target element or -1 if not found.
# *   The experiment measured the time complexity for various input sizes (`n`) ranging from 100 to 100,000.
# *   For each input size, a sorted list was generated, and the search target was set to `n-1` to simulate a near worst-case scenario where the element is found at the end of the list.
# *   The measured times for linear search were:
#     *   `n = 100`: 8.08e-05 seconds
#     *   `n = 1,000`: 3.84e-04 seconds
#     *   `n = 5,000`: 3.05e-03 seconds
#     *   `n = 10,000`: 4.38e-03 seconds
#     *   `n = 50,000`: 3.55e-02 seconds
#     *   `n = 100,000`: 5.40e-02 seconds
# *   The plot of time taken versus input size `n` (on a log-log scale) shows an approximately linear relationship, indicating that the time taken for linear search scales roughly linearly with the input size.
# *   This experimental observation confirms the theoretical time complexity of Linear Search, which is O(n) in the worst and average cases.
#
# ### Insights or Next Steps
#
# *   The experimental results strongly support the theoretical O(n) time complexity of linear search, demonstrating that its performance degrades linearly with increasing input size in worst-case scenarios.
# *   Further analysis could involve measuring the best-case (element at the beginning) and average-case performance, or comparing linear search to more efficient algorithms like binary search for sorted data.

# %% [markdown]
# # Task
# Implement a recursive binary search function, prepare experiment data with varying input sizes and sorted lists, run the experiment to measure time complexity, plot a graph to visualize the relationship between input size and time taken, and finally summarize the implementation, methodology, and observations from the plot in relation to the theoretical time complexity.

# %% [markdown]
# ## Implement Recursive Binary Search Function
#
# ### Subtask:
# Complete the `binary_search` function to correctly implement the recursive binary search algorithm. The function should return the index of the element if found, or -1 if not found. Handle edge cases such as an empty array or the element not being present.

# %% [markdown]
# **Reasoning**:
# The existing `binary_search` function needs to be completed according to the instructions provided, by adding recursive calls for the left and right halves of the array and a return statement for when the element is not found.

# %%
def binary_search(arr, low, high, x):
    if high >= low:
        mid = (high + low) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
        else:
            return binary_search(arr, mid + 1, high, x)
    else:
        return -1

# %% [markdown]
# ## Prepare Experiment Data for Binary Search
#
# ### Subtask:
# Define a range of input sizes (n values) for which the recursive binary search performance will be measured. For each 'n', create a *sorted* list of that size, as binary search requires sorted input.

# %% [markdown]
# **Reasoning**:
# The subtask requires defining input sizes, initializing a list for times, and generating sorted lists for each input size. Although similar steps were performed for linear search, re-initializing these for the binary search experiment ensures a clean slate and explicitly fulfills the current subtask's requirements. The `numpy` and `time` libraries are imported as per the instructions.

# %%
import numpy as np
import time

n_values = [100, 1000, 5000, 10000, 50000, 100000]
times = []

data_lists = []
for n in n_values:
    data_lists.append(np.arange(n)) # Create a sorted list of size n

print("Input sizes (n_values):", n_values)
print("Number of data lists generated:", len(data_lists))
# Out:
# Input sizes (n_values): [100, 1000, 5000, 10000, 50000, 100000]
# Number of data lists generated: 6

# %% [markdown]
# **Reasoning**:
# The experiment data (n_values and data_lists) has been prepared. The next logical step is to run the recursive binary search function for each input size and measure the time taken, storing these measurements for later plotting and analysis.

# %%
times = [] # Reset times list for binary search experiment
for i, n in enumerate(n_values):
    arr = data_lists[i]
    # Search for an element likely to be found, for example, a middle element or the last element.
    # For simplicity and consistency with linear search's near worst-case, let's search for the last element (n-1).
    element_to_find = n - 1

    start_time = time.time()
    # Call the binary_search function with initial low=0 and high=n-1
    binary_search(arr, 0, n - 1, element_to_find)
    end_time = time.time()
    times.append(end_time - start_time)

print("Measured times for recursive binary search:", times)
# Out:
# Measured times for recursive binary search: [2.1696090698242188e-05, 1.0728836059570312e-05, 9.775161743164062e-06, 8.58306884765625e-06, 1.1205673217773438e-05, 1.1444091796875e-05]

# %% [markdown]
# **Reasoning**:
# The times for the recursive binary search have been measured for various input sizes. The next step is to visualize this data by plotting the measured times against the input sizes to observe the time complexity.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(n_values, times, marker='o', linestyle='-', color='red')
plt.title('Recursive Binary Search Time Complexity')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.xscale('log') # Use a log scale for better visualization if n_values vary widely
plt.yscale('log') # Use a log scale for better visualization if times vary widely
plt.show()

# %% [markdown]
# ## Summary and Analysis
#
# ### Implementation:
# The `binary_search` function was implemented recursively. It takes the array `arr`, lower bound `low`, upper bound `high`, and the target element `x` as input. It calculates the middle index `mid`. If `arr[mid]` matches `x`, `mid` is returned. If `arr[mid]` is greater than `x`, the search continues in the left half (`low` to `mid - 1`). If `arr[mid]` is less than `x`, the search continues in the right half (`mid + 1` to `high`). The base case for recursion is when `high < low`, in which case -1 is returned, indicating the element is not found.
#
# ### Methodology:
# To determine the time complexity, the experiment involved:
# 1.  Defining a set of varying input sizes (`n_values`: 100, 1000, 5000, 10000, 50000, 100000).
# 2.  For each `n`, a sorted list of that size was generated using `np.arange(n)`, as binary search requires sorted input.
# 3.  The `binary_search` function was called for each list, searching for the last element (`n-1`). This choice represents finding an existing element within the array.
# 4.  The time taken for each search operation was measured using `time.time()` before and after the function call.
# 5.  These measured times were stored in the `times` list.
# 6.  A log-log plot was generated to visualize the relationship between input size and time taken.
#
# ### Observations from the Plot:
# The plot titled 'Recursive Binary Search Time Complexity' visualizes the relationship between the input size (`n`) and the time taken (seconds) for the recursive binary search algorithm. Both axes are on a logarithmic scale.
#
# From the plot, it can be observed that as the input size `n` increases significantly, the time taken for binary search remains relatively constant or increases very slowly. On a log-log scale, the data points for time taken appear to be nearly horizontal, which suggests that the time complexity is logarithmic, not linear. This is consistent with the theoretical time complexity of Binary Search, which is O(log n) in the worst and average cases, meaning the number of operations grows very slowly with the input size. Unlike linear search, the performance of binary search does not visibly degrade with a linear increase in input size, showcasing its efficiency for large datasets.
#
# ### Data Analysis Key Findings
#
# *   The `binary_search` function was correctly implemented recursively, handling both element finding and the base case of not finding the element.
# *   The experiment measured the time complexity for various input sizes (`n`) ranging from 100 to 100,000.
# *   For each input size, a sorted list was generated, and the search target was set to `n-1` to represent a search for an existing element.
# *   The measured times for recursive binary search were extremely small and did not show a clear increasing trend with `n`, especially when compared to linear search times.
#     *   `n = 100`: 2.17e-05 seconds
#     *   `n = 1,000`: 1.07e-05 seconds
#     *   `n = 5,000`: 9.78e-06 seconds
#     *   `n = 10,000`: 8.58e-06 seconds
#     *   `n = 50,000`: 1.12e-05 seconds
#     *   `n = 100,000`: 1.14e-05 seconds
# *   The log-log plot of time taken versus input size `n` showed a nearly flat line, indicating that the time taken for binary search scales logarithmically with the input size. The minor fluctuations are likely due to system overheads and the very small absolute values of time measured.
# *   This experimental observation strongly confirms the theoretical time complexity of Recursive Binary Search, which is O(log n).
#
# ### Insights or Next Steps
#
# *   The experimental results underscore the significant efficiency advantage of binary search over linear search for sorted data, especially as the input size grows. While linear search showed a clear linear increase in time, binary search's time remained almost constant.
# *   To get more precise measurements for very fast algorithms like binary search, multiple runs and averaging of times, or using a specialized benchmarking library like `timeit`, would be beneficial to minimize the impact of system noise.
# *   Further analysis could involve comparing the constant factors of different implementations or comparing its performance to iterative binary search.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the implementation of the recursive binary search, detail the methodology used for measuring its time complexity, and discuss the observations drawn from the generated performance graph, relating them to the theoretical time complexity of binary search.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The recursive binary search function was correctly implemented. It efficiently finds an element in a sorted array by repeatedly dividing the search interval in half. It returns the index if found, and -1 otherwise.
# *   The experiment measured the time taken for the recursive binary search across varying input sizes: \[100, 1,000, 5,000, 10,000, 50,000, 100,000].
# *   For each input size, a sorted array was generated, and the search target was set to the last element (\`n-1\`) to simulate finding an existing element.
# *   The measured execution times for the recursive binary search were extremely small, ranging from approximately 8.58e-06 to 2.17e-05 seconds. Crucially, these times did not show a clear increasing trend with larger input sizes.
#     *   For \`n = 100\`, time taken was approximately 2.17e-05 seconds.
#     *   For \`n = 100,000\`, time taken was approximately 1.14e-05 seconds.
# *   A log-log plot visualizing input size versus time taken revealed a nearly horizontal line, indicating that the time complexity grows logarithmically with the input size. This observation empirically confirms the theoretical time complexity of recursive binary search, which is O(log n).
#
# ### Insights or Next Steps
#
# *   The experimental results underscore binary search's exceptional efficiency for sorted data, demonstrating its significant performance advantage over algorithms with linear time complexity as input sizes grow.
# *   To refine the accuracy of time measurements for such fast algorithms, future experiments could employ techniques like averaging results over multiple runs or utilizing specialized benchmarking tools like Python's `timeit` module to mitigate system noise and overhead.

# %% [markdown]
# # Task
# Implement the `insertion_sort` function based on the provided algorithm. The function should take a list as input and sort it in place.

# %% [markdown]
# ## Implement Insertion Sort Function
#
# ### Subtask:
# Implement the `insertion_sort` function based on the provided algorithm. The function should take a list as input and sort it in place.

# %% [markdown]
# **Reasoning**:
# The subtask explicitly asks for the implementation of the `insertion_sort` function based on the provided algorithm. I will create a `code_block` containing this function.

# %%
def insertion_sort(arr):
    # Iterate over the array from the second element to the end
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        # Move elements of arr[0..i-1], that are greater than key,
        # to one position ahead of their current position
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

print("Insertion sort function defined.")
# Out:
# Insertion sort function defined.

# %% [markdown]
# ## Prepare Experiment Data
#
# ### Subtask:
# Define a range of input sizes (n values) for which the insertion sort performance will be measured. For each 'n', create a list of 'n' unsorted (e.g., randomly generated) elements to ensure consistent test conditions for worst-case or average-case scenarios.

# %% [markdown]
# **Reasoning**:
# The subtask requires importing `numpy`, defining a range of input sizes (`n_values`), initializing an empty list for data (`data_lists`), and then populating `data_lists` with unsorted random integer lists for each `n` to prepare the experiment data for insertion sort. I will consolidate these steps into a single code block.

# %%
import numpy as np

n_values = [100, 1000, 5000, 10000, 50000, 100000] # Defined input sizes
data_lists = [] # Initialize list to store unsorted arrays

for n in n_values:
    # Generate a list of n random integers between 0 and n-1
    data_lists.append(np.random.randint(0, n, n).tolist())

print("Input sizes (n_values):", n_values)
print("Number of unsorted data lists generated:", len(data_lists))
# Out:
# Input sizes (n_values): [100, 1000, 5000, 10000, 50000, 100000]
# Number of unsorted data lists generated: 6

# %% [markdown]
# **Reasoning**:
# Now that the `data_lists` are prepared with unsorted arrays, the next step is to measure the time taken by the `insertion_sort` function for each input size. This involves importing the `time` module, iterating through `n_values` and `data_lists`, making a copy of each list before sorting (as `insertion_sort` sorts in-place to avoid modifying the original `data_lists` for potential future use or re-runs with the same initial data if needed, though for this task it's not strictly necessary, it's good practice), measuring the execution time, and storing it in the `times` list.

# %%
import time

times = [] # Initialize list to store execution times

for i, n in enumerate(n_values):
    arr_to_sort = data_lists[i].copy() # Make a copy to preserve original unsorted list

    start_time = time.time()
    insertion_sort(arr_to_sort)
    end_time = time.time()
    times.append(end_time - start_time)

print("Measured times for insertion sort:", times)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2341555195.py in <cell line: 0>()
#       7
#       8     start_time = time.time()
# ----> 9     insertion_sort(arr_to_sort)
#      10     end_time = time.time()
#      11     times.append(end_time - start_time)
#
# /tmp/ipython-input-2737516904.py in insertion_sort(arr)
#       7         # Move elements of arr[0..i-1], that are greater than key,
#       8         # to one position ahead of their current position
# ----> 9         while j >= 0 and arr[j] > key:
#      10             arr[j + 1] = arr[j]
#      11             j -= 1
#
# KeyboardInterrupt:
